# %%
pip install --upgrade pillow
# Out:
# Requirement already up-to-date: pillow in c:\users\bevan\anaconda3\lib\site-packages (7.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle

pickle_in=open("X.pickle","rb")
X=pickle.load(pickle_in)

pickle_in=open("y.pickle","rb")
y=pickle.load(pickle_in)

X=np.array(X).reshape(-1,224,224,1)

# %%
import numpy as np
import keras
from keras import backend as K
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_path="C:/Users/BEVAN/Downloads/observations-master/observations-master/experiements/data"
test_path="C:/Users/BEVAN/PycharmProjects/MaskDetection/Data"

# %%
train_batch=ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(train_path,target_size=(224,224),batch_size=10)
test_batch=ImageDataGenerator(preprocessing_function=keras.applications.mobilenet.preprocess_input).flow_from_directory(test_path,target_size=(224,224),batch_size=10,shuffle=False)
# Out:
# Found 1376 images belonging to 2 classes.
# Found 738 images belonging to 2 classes.

# %%
mobile=keras.applications.mobilenet.MobileNet()

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# ...

# %%
x=mobile.layers[-7].output
x=keras.layers.AveragePooling2D(pool_size=(7,7))(x)
x=keras.layers.Flatten()(x)
x=keras.layers.Dense(128,activation='relu')(x)
x=keras.layers.Dropout(0.5)(x)
x=keras.layers.Dense(2,activation='softmax')(x)
model=Model(input=mobile.input,outputs=x)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# ...

# %%
model.compile(Adam(lr=.0001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(train_batch,steps_per_epoch=12,epochs=30,verbose=2)
# Out:
# Epoch 1/30
#  - 15s - loss: 0.6525 - accuracy: 0.7000
# Epoch 2/30
#  - 4s - loss: 0.2762 - accuracy: 0.8750
# Epoch 3/30
#  - 4s - loss: 0.1397 - accuracy: 0.9500
# Epoch 4/30
#  - 4s - loss: 0.0537 - accuracy: 0.9917
# Epoch 5/30
#  - 4s - loss: 0.0882 - accuracy: 0.9833
# Epoch 6/30
#  - 4s - loss: 0.0647 - accuracy: 0.9583
# Epoch 7/30
#  - 4s - loss: 0.0476 - accuracy: 0.9833
# Epoch 8/30
#  - 4s - loss: 0.0788 - accuracy: 0.9750
# Epoch 9/30
#  - 5s - loss: 0.1235 - accuracy: 0.9655
# Epoch 10/30
#  - 4s - loss: 0.0541 - accuracy: 0.9833
# Epoch 11/30
#  - 4s - loss: 0.0380 - accuracy: 0.9917
# Epoch 12/30
#  - 4s - loss: 0.0151 - accuracy: 1.0000
# Epoch 13/30
#  - 4s - loss: 0.0174 - accuracy: 0.9917
# Epoch 14/30
#  - 4s - loss: 0.0514 - accuracy: 0.9750
# Epoch 15/30
#  - 4s - loss: 0.0291 - accuracy: 0.9917
# Epoch 16/30
#  - 4s - loss: 0.0210 - accuracy: 0.9833
# Epoch 17/30
#  - 4s - loss: 0.0267 - accuracy: 0.9917
# Epoch 18/30
#  - 4s - loss: 0.0192 - accuracy: 0.9917
# ...

# %%
img_width, img_height = 224, 224
img = image.load_img('C:/Users/BEVAN/PycharmProjects/MaskDetection/ex.jpeg', target_size = (img_width, img_height))
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)

# %%
predict=model.predict(img)

# %%
print(predict)
# Out:
# [[0.15377298 0.84622705]]

# %%
from sklearn.metrics import confusion_matrix

# %%
test_labels=test_batch.classes

# %%
predictions=model.predict_generator(test_batch,steps=1,verbose=0)

# %%
predictions.shape
# Out:
# (10, 2)

# %%
cm=confusion_matrix(test_labels,predictions.argmax(axis=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-50c280f56f21> in <module>
# ----> 1 cm=confusion_matrix(test_labels,predictions.argmax(axis=1))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
#      82     type_pred = type_of_target(y_pred)
#
# ...
